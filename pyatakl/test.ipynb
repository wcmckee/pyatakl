# %%
import pyatakl
import unittest

# %%
savpark = pyatakl.parks()

# %%
savpark.getparks(.ipynb_checkpoints.ipynb_checkpoints.ipynb_checkpoints.ipynb_checkpoints
# Out:
# [{u'address': u' Beach Road Te Atatu North Auckland',
#   u'id': u'2',
#   u'latitude': -36.828734,
#   u'longitude': 174.656176,
#   u'mobilitySpaces': 0,
#   u'name': u'Beach Road Carpark, Te Atatu North',
#   u'type': u'all'},
#  {u'address': u'5 City Rd Grafton Auckland',
#   u'id': u'3',
#   u'latitude': -36.856949,
#   u'longitude': 174.7639059,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 5-7 City Road',
#   u'type': u'motorcycle'},
#  {u'address': u' Harbour View Road Te Atatu Penisula Auckland',
#   u'id': u'4',
#   u'latitude': -36.839193,
#   u'longitude': 174.66168,
#   u'mobilitySpaces': 0,
#   u'name': u'Harbour View Road Carpark, Te Atatu Penisula',
#   u'type': u'all'},
#  {u'address': u'6 Burleigh St Grafton Auckland',
#   u'id': u'5',
#   u'latitude': -36.8649142,
#   u'longitude': 174.7625287,
#   u'mobilitySpaces': 0,
#   u'name': u'Burleigh Street, Grafton (Corner Burleigh and Khyber Pass Road)',
#   u'type': u'all'},
#  {u'address': u' McLeod Road Te Atatu South Auckland',
#   u'id': u'6',
#   u'latitude': -36.875892,
#   u'longitude': 174.655774,
#   u'mobilitySpaces': 0,
#   u'name': u'McLeod Road Carpark, Te Atatu South',
#   u'type': u'all'},
#  {u'address': u' Glenmall Place Glen Eden Auckland',
#   u'id': u'8',
#   u'latitude': -36.911239,
#   u'longitude': 174.651997,
#   u'mobilitySpaces': 0,
#   u'name': u'Glenmall Place Carpark, Glen Eden (Mobility, P45, P125, LZ',
#   u'type': u'all'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'9',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes 6 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Matipo Road Te Atatu Peninsula Auckland',
#   u'id': u'10',
#   u'latitude': -36.837484,
#   u'longitude': 174.642153,
#   u'mobilitySpaces': 0,
#   u'name': u'Matipo Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Mayoral Drive CBD Auckland',
#   u'id': u'11',
#   u'latitude': -36.853726,
#   u'longitude': 174.76451,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking opposite the Open Polytechnic at 120 Mayoral Drive',
#   u'type': u'mobility'},
#  {u'address': u' Old Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'12',
#   u'latitude': -36.84893,
#   u'longitude': 174.651021,
#   u'mobilitySpaces': 0,
#   u'name': u'Old Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'30 Princes Street CBD Auckland',
#   u'id': u'13',
#   u'latitude': -36.851495,
#   u'longitude': 174.768538,
#   u'mobilitySpaces': 3,
#   u'name': u'On street mobility parking outside the Maidement Art Centre',
#   u'type': u'mobility'},
#  {u'address': u' South Titirangi Road Titirangi Auckland',
#   u'id': u'14',
#   u'latitude': -36.938865,
#   u'longitude': 174.655945,
#   u'mobilitySpaces': 0,
#   u'name': u'South Titirangi Road Carpark, Titirangi (Mobililty)',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'15',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 15,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes 15 Mobility parking spaces on the ground level. ',
#   u'type': u'all'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'16',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Granville Road Royal Heights Auckland',
#   u'id': u'17',
#   u'latitude': -36.828674,
#   u'longitude': 174.628286,
#   u'mobilitySpaces': 0,
#   u'name': u'Granville Road Carpark, Royal Heights',
#   u'type': u'all'},
#  {u'address': u'45 Airedale Street CBD Auckland',
#   u'id': u'18',
#   u'latitude': -36.854895,
#   u'longitude': 174.764762,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking',
#   u'type': u'mobility'},
#  {u'address': u' Henderson Valley Road Henderson Auckland',
#   u'id': u'20',
#   u'latitude': -36.894187,
#   u'longitude': 174.616538,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Valley Road, Henderson',
#   u'type': u'all'},
#  {u'address': u' Henderson Park Henderson Auckland',
#   u'id': u'21',
#   u'latitude': -36.878807,
#   u'longitude': 174.625255,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Park, Henderson',
#   u'type': u'all'},
#  {u'address': u' Waipareira Avenue Lincoln Auckland',
#   u'id': u'22',
#   u'latitude': -36.865017,
#   u'longitude': 174.633173,
#   u'mobilitySpaces': 0,
#   u'name': u'Waipareira Avenue Carpark (Mobility), Lincoln',
#   u'type': u'all'},
#  {u'address': u' Withers Road Glen Eden Auckland',
#   u'id': u'23',
#   u'latitude': -36.926616,
#   u'longitude': 174.643081,
#   u'mobilitySpaces': 0,
#   u'name': u'Withers Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u'24 Wellesley St W Auckland Auckland',
#   u'id': u'24',
#   u'latitude': -36.8508833,
#   u'longitude': 174.7632388,
#   u'mobilitySpaces': 0,
#   u'name': u'Bledisloe',
#   u'type': u'all'},
#  {u'address': u' Titirangi Road Titirangi Auckland',
#   u'id': u'25',
#   u'latitude': -36.938091,
#   u'longitude': 174.656181,
#   u'mobilitySpaces': 0,
#   u'name': u'Titirangi Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Clearwater Cove , Royal Heights Auckland',
#   u'id': u'26',
#   u'latitude': -36.810603,
#   u'longitude': 174.645184,
#   u'mobilitySpaces': 0,
#   u'name': u'Clearwater Cove Carpark, Royal Heights',
#   u'type': u'all'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'27',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'28',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 21,
#   u'name': u'Multi storey parking facility under Aotea square. Includes 21 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u' Titirangi Road Titirangi Auckland',
#   u'id': u'29',
#   u'latitude': -36.938134,
#   u'longitude': 174.655441,
#   u'mobilitySpaces': 0,
#   u'name': u'Titirangi Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Taikata Road Te Atatu Peninsula Auckland',
#   u'id': u'30',
#   u'latitude': -36.836561,
#   u'longitude': 174.638983,
#   u'mobilitySpaces': 0,
#   u'name': u'Taikata Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'22 Symonds St CBD Auckland',
#   u'id': u'31',
#   u'latitude': -36.853223,
#   u'longitude': 174.7696247,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 20-26 Symonds Street',
#   u'type': u'motorcycle'},
#  {u'address': u'21 Federal Street CBD Auckland',
#   u'id': u'32',
#   u'latitude': -36.84553,
#   u'longitude': 174.763762,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking on corner of Federal and Swanson Street',
#   u'type': u'mobility'},
#  {u'address': u'100-102 Customs Street West CBD Auckland',
#   u'id': u'33',
#   u'latitude': -36.843747,
#   u'longitude': 174.763149,
#   u'mobilitySpaces': 2,
#   u'name': u'On Street mobility parking outside Auckland Tepid Baths.  ',
#   u'type': u'mobility'},
#  {u'address': u'34 Airedale St CBD Auckland',
#   u'id': u'34',
#   u'latitude': -36.8546386,
#   u'longitude': 174.7648333,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 34 Airdale Street',
#   u'type': u'motorcycle'},
#  {u'address': u'2 Chancery St CBD Auckland',
#   u'id': u'35',
#   u'latitude': -36.8476481,
#   u'longitude': 174.7671923,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 2-8 Chancery Street',
#   u'type': u'motorcycle'},
#  {u'address': u'123 Pakenham St W CBD Auckland',
#   u'id': u'36',
#   u'latitude': -36.843373,
#   u'longitude': 174.7562491,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 117- 139 Pakenham Street West',
#   u'type': u'motorcycle'},
#  {u'address': u'20 Upper Queen St Auckland Auckland',
#   u'id': u'37',
#   u'latitude': -36.8589737,
#   u'longitude': 174.7615222,
#   u'mobilitySpaces': 0,
#   u'name': u'Upper Queen Street,(opposite Cross Street)',
#   u'type': u'all'},
#  {u'address': u' West Coast Road Glen Eden Auckland',
#   u'id': u'38',
#   u'latitude': -36.910222,
#   u'longitude': 174.652512,
#   u'mobilitySpaces': 0,
#   u'name': u'West Coast Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u' 64 CBD Auckland',
#   u'id': u'39',
#   u'latitude': -36.854233,
#   u'longitude': 174.761174,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking near Myers Park',
#   u'type': u'mobility'},
#  {u'address': u' Ratanui Street Henderson Auckland',
#   u'id': u'40',
#   u'latitude': -36.879194,
#   u'longitude': 174.632591,
#   u'mobilitySpaces': 0,
#   u'name': u'Ratanui Street Carpark (Mobility), Henderson',
#   u'type': u'all'},
#  {u'address': u' Edmonton Road Henderson Auckland',
#   u'id': u'41',
#   u'latitude': -36.878235,
#   u'longitude': 174.634761,
#   u'mobilitySpaces': 0,
#   u'name': u'Edmonton Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Robertson Road Ranui Auckland',
#   u'id': u'42',
#   u'latitude': -36.866566,
#   u'longitude': 174.600456,
#   u'mobilitySpaces': 0,
#   u'name': u'Robertson Road Carpark, Ranui',
#   u'type': u'all'},
#  {u'address': u'9 Wolfe Street CBD Auckland',
#   u'id': u'43',
#   u'latitude': -36.844975,
#   u'longitude': 174.764319,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking',
#   u'type': u'mobility'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'44',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes 6 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'22 Princes Street CBD Auckland',
#   u'id': u'45',
#   u'latitude': -36.850084,
#   u'longitude': 174.769182,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside Auckland University Clock Tower',
#   u'type': u'mobility'},
#  {u'address': u'112 Parnell Rd Parnell Auckland',
#   u'id': u'47',
#   u'latitude': -36.852955,
#   u'longitude': 174.7790622,
#   u'mobilitySpaces': 0,
#   u'name': u'112 Parnell Road (Entrance off Garfield street) \u200b',
#   u'type': u'all'},
#  {u'address': u'7 Elliott St CBD Auckland',
#   u'id': u'48',
#   u'latitude': -36.8492861,
#   u'longitude': 174.7640473,
#   u'mobilitySpaces': 0,
#   u'name': u'Cnr Elliot & Victoria Streets, Auckland',
#   u'type': u'motorcycle'},
#  {u'address': u' La Rosa Street Green Bay Auckland',
#   u'id': u'49',
#   u'latitude': -36.9304,
#   u'longitude': 174.67526,
#   u'mobilitySpaces': 0,
#   u'name': u'La Rosa Street Carpark, Green Bay',
#   u'type': u'all'},
#  {u'address': u'2 Daldy St CBD Auckland',
#   u'id': u'50',
#   u'latitude': -36.8451709,
#   u'longitude': 174.7539487,
#   u'mobilitySpaces': 0,
#   u'name': u'Opposite 2 Daldy Street',
#   u'type': u'motorcycle'},
#  {u'address': u' Sel Peacock Driven Henderson Auckland',
#   u'id': u'51',
#   u'latitude': -36.879194,
#   u'longitude': 174.632591,
#   u'mobilitySpaces': 0,
#   u'name': u'Sel Peacock Drive (Mobility), Henderson',
#   u'type': u'all'},
#  {u'address': u' Binstead Road Kelston Auckland',
#   u'id': u'52',
#   u'latitude': -36.901476,
#   u'longitude': 174.681416,
#   u'mobilitySpaces': 0,
#   u'name': u'Binstead Road Carpark, Kelston',
#   u'type': u'all'},
#  {u'address': u'16 Eden Crescent CBD Auckland',
#   u'id': u'53',
#   u'latitude': -36.8481902,
#   u'longitude': 174.7720016,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 16-18 Eden Crescent ',
#   u'type': u'motorcycle'},
#  {u'address': u' Totara Avenue New Lynn Auckland',
#   u'id': u'54',
#   u'latitude': -36.910003,
#   u'longitude': 174.68134,
#   u'mobilitySpaces': 0,
#   u'name': u'Totara Avenue Carpark, New Lynn (Mobility, P240)',
#   u'type': u'all'},
#  {u'address': u' Swanson Road Henderson Auckland',
#   u'id': u'55',
#   u'latitude': -36.872744,
#   u'longitude': 174.620967,
#   u'mobilitySpaces': 0,
#   u'name': u'Swanson Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'56',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Whatipu Road Huia Auckland',
#   u'id': u'57',
#   u'latitude': -37.016732,
#   u'longitude': 174.553378,
#   u'mobilitySpaces': 0,
#   u'name': u'Whatipu Road Carpark, Huia',
#   u'type': u'all'},
#  {u'address': u' Beaubank Road  Kelston Beaubank Road  Kelston Auckland',
#   u'id': u'58',
#   u'latitude': -36.896336,
#   u'longitude': 174.671824,
#   u'mobilitySpaces': 0,
#   u'name': u'Beaubank Road Carpark, Kelston',
#   u'type': u'all'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'59',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 4,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes 4 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Central Park Drive Henderson Auckland',
#   u'id': u'60',
#   u'latitude': -36.86321,
#   u'longitude': 174.636338,
#   u'mobilitySpaces': 0,
#   u'name': u'Central Park Drive Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'2 Kitchener Street CBD Auckland',
#   u'id': u'61',
#   u'latitude': -36.850649,
#   u'longitude': 174.766161,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking near the Auckland Art Gallery',
#   u'type': u'mobility'},
#  {u'address': u'182 Federal St CBD Auckland',
#   u'id': u'62',
#   u'latitude': -36.8504856,
#   u'longitude': 174.7617902,
#   u'mobilitySpaces': 0,
#   u'name': u'Cnr Federal & Wellesley Streets, Auckland',
#   u'type': u'motorcycle'},
#  {u'address': u'65 Federal Street CBD Auckland',
#   u'id': u'63',
#   u'latitude': -36.847672,
#   u'longitude': 174.762814,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 65 Federal Street',
#   u'type': u'mobility'},
#  {u'address': u'48 Market Place CBD Auckland',
#   u'id': u'64',
#   u'latitude': -36.843579,
#   u'longitude': 174.761774,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 48 Market Place',
#   u'type': u'mobility'},
#  {u'address': u'57 Anzac Avenue CBD Auckland',
#   u'id': u'65',
#   u'latitude': -36.847314,
#   u'longitude': 174.772383,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking, outside the New Zealand Customs building',
#   u'type': u'mobility'},
#  {u'address': u'11 St Paul Street CBD Auckland',
#   u'id': u'66',
#   u'latitude': -36.8539462,
#   u'longitude': 174.7673425,
#   u'mobilitySpaces': 0,
#   u'name': u'11 St Paul Street, Auckland, New Zealand',
#   u'type': u'motorcycle'},
#  {u'address': u' Marine Parade Piha Auckland',
#   u'id': u'67',
#   u'latitude': -36.955628,
#   u'longitude': 174.468373,
#   u'mobilitySpaces': 0,
#   u'name': u'Marine Parade South (North Carpark), Piha (Mobility)',
#   u'type': u'all'},
#  {u'address': u' Marine Parade Piha Auckland',
#   u'id': u'68',
#   u'latitude': -36.957587,
#   u'longitude': 174.468142,
#   u'mobilitySpaces': 0,
#   u'name': u'Marine Parade South (South Carpark), Piha',
#   u'type': u'all'},
#  {u'address': u' Essex Street Henderson Auckland',
#   u'id': u'69',
#   u'latitude': -36.87171,
#   u'longitude': 174.642915,
#   u'mobilitySpaces': 0,
#   u'name': u'Essex Street Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Turner Street CBD Auckland',
#   u'id': u'70',
#   u'latitude': -36.855519,
#   u'longitude': 174.763256,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking, opposite Auckland International YHA',
#   u'type': u'mobility'},
#  {u'address': u'125 Customs Street West CBD Auckland',
#   u'id': u'71',
#   u'latitude': -36.84382,
#   u'longitude': 174.760361,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 125 Customs Street West',
#   u'type': u'mobility'},
#  {u'address': u'9-11 Symonds St CBD Auckland',
#   u'id': u'72',
#   u'latitude': -36.8522447,
#   u'longitude': 174.7697629,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 9 -11 Symonds Street',
#   u'type': u'motorcycle'},
#  {u'address': u' Great North Road Henderson Auckland',
#   u'id': u'73',
#   u'latitude': -36.87171,
#   u'longitude': 174.642915,
#   u'mobilitySpaces': 0,
#   u'name': u'Great North Road (426) Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'74',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes 6 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Te Pai Place Lincoln Auckland',
#   u'id': u'76',
#   u'latitude': -36.862047,
#   u'longitude': 174.632884,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Pai Place Carpark, Lincoln',
#   u'type': u'all'},
#  {u'address': u'26-46 Te Taou Crescent CBD Auckland',
#   u'id': u'77',
#   u'latitude': -36.848544,
#   u'longitude': 174.776416,
#   u'mobilitySpaces': 5,
#   u'name': u'On street mobility parking beside the old Grand Central Station, next to Vector Arena.',
#   u'type': u'mobility'},
#  {u'address': u' Anzac Street Takapuna, Auckland',
#   u'id': u'78',
#   u'latitude': -36.786656,
#   u'longitude': 174.77127,
#   u'mobilitySpaces': 0,
#   u'name': u'Anzac Street, Takapuna. Includes 8 Mobility parking spaces.',
#   u'type': u'all'},
#  {u'address': u' Tyler Street CBD Auckland',
#   u'id': u'79',
#   u'latitude': -36.844474,
#   u'longitude': 174.770004,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking, halfway down Tyler Street.',
#   u'type': u'mobility'},
#  {u'address': u' Glendale Road Glen Eden Auckland',
#   u'id': u'80',
#   u'latitude': -36.9204,
#   u'longitude': 174.649508,
#   u'mobilitySpaces': 0,
#   u'name': u'Glendale Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u'52-60 Federal Street CDB Auckland',
#   u'id': u'81',
#   u'latitude': -36.847889,
#   u'longitude': 174.762807,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking outside 60 Federal Street',
#   u'type': u'mobility'},
#  {u'address': u'51 High Street CBD Auckland',
#   u'id': u'82',
#   u'latitude': -36.848418,
#   u'longitude': 174.766358,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 51 High Street',
#   u'type': u'mobility'},
#  {u'address': u' Don Buck Road Massey Auckland',
#   u'id': u'88',
#   u'latitude': -36.834427,
#   u'longitude': 174.603058,
#   u'mobilitySpaces': 0,
#   u'name': u'Don Buck Road Carpark, Massey',
#   u'type': u'all'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'90',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'20 Greys Ave Auckland Auckland',
#   u'id': u'91',
#   u'latitude': -36.8528506,
#   u'longitude': 174.7630503,
#   u'mobilitySpaces': 0,
#   u'name': u'Greys Ave\u200b (opposite the Civic Building)',
#   u'type': u'all'},
#  {u'address': u' Parrs Cross Road Glen Eden Auckland',
#   u'id': u'92',
#   u'latitude': -36.906675,
#   u'longitude': 174.627723,
#   u'mobilitySpaces': 0,
#   u'name': u'Parrs Cross Road Carpark, Glen Eden/Oratia',
#   u'type': u'all'},
#  {u'address': u' Great North Road New Lynn Auckland',
#   u'id': u'93',
#   u'latitude': -36.908669,
#   u'longitude': 174.682869,
#   u'mobilitySpaces': 0,
#   u'name': u'Great North Road (3072) Carpark, New Lynn (Mobility, P120, P180, LZ)',
#   u'type': u'all'},
#  {u'address': u'360 Queen Street CBD Auckland',
#   u'id': u'94',
#   u'latitude': -36.852541,
#   u'longitude': 174.763875,
#   u'mobilitySpaces': 3,
#   u'name': u'On street mobility parking opposite the Town Hall',
#   u'type': u'mobility'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'95',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 9,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes 9 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'96',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 21,
#   u'name': u'Multi storey parking facility under Aotea square. Includes 21 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Taitoki Street Te Atatu Peninsula Auckland',
#   u'id': u'97',
#   u'latitude': -36.855158,
#   u'longitude': 174.647405,
#   u'mobilitySpaces': 0,
#   u'name': u'Taitoki Street Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'33 Wyndham Street CBD Auckland',
#   u'id': u'98',
#   u'latitude': -36.846787,
#   u'longitude': 174.763832,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking near St Patricks Church.',
#   u'type': u'mobility'},
#  {u'address': u'126 Beach Rd Auckland Auckland',
#   u'id': u'99',
#   u'latitude': -36.8482474,
#   u'longitude': 174.7746586,
#   u'mobilitySpaces': 0,
#   u'name': u' Railway station, Beach Road,(Opposite Tai Ping Supermarket)',
#   u'type': u'all'},
#  {u'address': u' Don Buck Road Massey Auckland',
#   u'id': u'100',
#   u'latitude': -36.836016,
#   u'longitude': 174.60228,
#   u'mobilitySpaces': 0,
#   u'name': u'Don Buck Road Carpark (P60), Massey',
#   u'type': u'all'},
#  {u'address': u'70 The Strand Parnell Auckland',
#   u'id': u'101',
#   u'latitude': -36.8495918,
#   u'longitude': 174.7813795,
#   u'mobilitySpaces': 0,
#   u'name': u'Corner of The Strand and St Georges Bay Rd Parnell\r\n(Opposite Saatchi & Saatchi)',
#   u'type': u'all'},
#  {u'address': u' Huia Road Titirangi Auckland',
#   u'id': u'102',
#   u'latitude': -36.949007,
#   u'longitude': 174.641781,
#   u'mobilitySpaces': 0,
#   u'name': u'Huia Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Willerton Avenue New Lynn Auckland',
#   u'id': u'103',
#   u'latitude': -36.918028,
#   u'longitude': 174.674769,
#   u'mobilitySpaces': 0,
#   u'name': u'Willerton Avenue Carpark, New Lynn',
#   u'type': u'all'},
#  {u'address': u' Parliament Street CBD Auckland',
#   u'id': u'104',
#   u'latitude': -36.849366,
#   u'longitude': 174.771821,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking Beside the Auckland High Court on the corner of Parliament Street and Waterloo Quadrant.',
#   u'type': u'mobility'},
#  {u'address': u' Neil Avenue Te Atatu Peninsula Auckland',
#   u'id': u'105',
#   u'latitude': -36.838506,
#   u'longitude': 174.646236,
#   u'mobilitySpaces': 0,
#   u'name': u'Neil Avenue Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'106',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Atkinson Road Titirangi Auckland',
#   u'id': u'107',
#   u'latitude': -36.924105,
#   u'longitude': 174.655522,
#   u'mobilitySpaces': 0,
#   u'name': u'Atkinson Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Atkinson Road Titirangi Auckland',
#   u'id': u'108',
#   u'latitude': -36.927017,
#   u'longitude': 174.655049,
#   u'mobilitySpaces': 0,
#   u'name': u'Atkinson Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Henderson Valley Road Henderson Auckland',
#   u'id': u'109',
#   u'latitude': -36.878702,
#   u'longitude': 174.629772,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Valley Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'110',
#   u'latitude': -36.841509,
#   u'longitude': 174.651855,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Wilsher Road Henderson Auckland',
#   u'id': u'112',
#   u'latitude': -36.878807,
#   u'longitude': 174.625255,
#   u'mobilitySpaces': 0,
#   u'name': u'Wilsher Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'113',
#   u'latitude': -36.840558,
#   u'longitude': 174.651576,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Moselle Avenue Lincoln Auckland',
#   u'id': u'114',
#   u'latitude': -36.864442,
#   u'longitude': 174.629686,
#   u'mobilitySpaces': 0,
#   u'name': u'Moselle Avenue Carpark (Mobility), Lincoln',
#   u'type': u'all'},
#  {u'address': u' Edmonton Road Te Atatu South Auckland',
#   u'id': u'115',
#   u'latitude': -36.866002,
#   u'longitude': 174.645313,
#   u'mobilitySpaces': 0,
#   u'name': u'Edmonton Road Carpark, Te Atatu South',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'116',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 15,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes 15 Mobility parking spaces on the ground level. ',
#   u'type': u'mobility'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'117',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes 6 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u' Red Hills Road Massey Auckland',
#   u'id': u'118',
#   u'latitude': -36.837502,
#   u'longitude': 174.598779,
#   u'mobilitySpaces': 0,
#   u'name': u'Red Hills Road Carpark, Massey',
#   u'type': u'all'},
#  {u'address': u' Alderman Drive Henderson Auckland',
#   u'id': u'119',
#   u'latitude': -36.877651,
#   u'longitude': 174.634976,
#   u'mobilitySpaces': 0,
#   u'name': u'Alderman Drive Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'121',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi storey parking facility under Aotea square. Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'12-42 Ngaoho Pl Parnell Auckland',
#   u'id': u'122',
#   u'latitude': -36.8493662,
#   u'longitude': 174.7768046,
#   u'mobilitySpaces': 0,
#   u'name': u'Ngaoho Place\u200b',
#   u'type': u'all'},
#  {u'address': u' West Coast Road Glen Eden Auckland',
#   u'id': u'123',
#   u'latitude': -36.909999,
#   u'longitude': 174.651724,
#   u'mobilitySpaces': 0,
#   u'name': u'West Coast Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u' Hugh Brown Drive New Lynn Auckland',
#   u'id': u'124',
#   u'latitude': -36.906947,
#   u'longitude': 174.681201,
#   u'mobilitySpaces': 0,
#   u'name': u'Hugh Brown Drive Carpark, New Lynn',
#   u'type': u'all'},
#  {u'address': u'21 St Paul Street CBD Auckland',
#   u'id': u'125',
#   u'latitude': -36.8539,
#   u'longitude': 174.766939,
#   u'mobilitySpaces': 4,
#   u'name': u'On street mobility parking outside AUT (AUckland University of Technology) D Block.',
#   u'type': u'mobility'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'126',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 4,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes 4 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'127',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 9,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes 9 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u'30 McCrae Way New Lynn Auckland',
#   u'id': u'128',
#   u'latitude': -36.909199,
#   u'longitude': 174.68318,
#   u'mobilitySpaces': 12,
#   u'name': u'Multi-storey pay and display parking facility under Totara Medical Centre. Three levels with 70 parking spaces and 4 mobility spaces on each level. The first level is reserved for visitors to the Totara Medical Centre. Limited motorcycle parking in designated areas.\r\n',
#   u'type': u'all'},
#  {u'address': u'14 Trading Place Henderson Auckland',
#   u'id': u'129',
#   u'latitude': -36.878711,
#   u'longitude': 174.633626,
#   u'mobilitySpaces': 7,
#   u'name': u'Henderson library/Unitec car park',
#   u'type': u'all'},
#  {u'address': u'7-9 Oceanview Rd Oneroa Auckland',
#   u'id': u'130',
#   u'latitude': -36.781143,
#   u'longitude': 174.993854,
#   u'mobilitySpaces': 12,
#   u'name': u'Matiatia car park (Waiheke Island)',
#   u'type': u'all'},
#  {u'address': u'22 Beresford Square CBD Auckland',
#   u'id': u'131',
#   u'latitude': -36.856566,
#   u'longitude': 174.757762,
#   u'mobilitySpaces': 0,
#   u'name': u'Beresford Square car park',
#   u'type': u'all'},
#  {u'address': u'1429 Sandspit Rd Sandspit Auckland',
#   u'id': u'132',
#   u'latitude': -36.390447,
#   u'longitude': 174.728553,
#   u'mobilitySpaces': 0,
#   u'name': u'Sandspit Road, Sandspit, off State Highway 1',
#   u'type': u'all'},
#  {u'address': u'4 Bakehouse Lane  Orewa Orewa',
#   u'id': u'133',
#   u'latitude': -36.586509,
#   u'longitude': 174.695507,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle park with drop kerb access ',
#   u'type': u'mobility'},
#  {u'address': u'18 Bakehouse Lane Orewa Orewa',
#   u'id': u'134',
#   u'latitude': -36.587053,
#   u'longitude': 174.695738,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle park with drop kerb ',
#   u'type': u'mobility'},
#  {u'address': u'15 Florence Street Orewa Orewa',
#   u'id': u'135',
#   u'latitude': -36.585012,
#   u'longitude': 174.693935,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle space located in Hillary Square North, outside the Red Cross Shop .',
#   u'type': u'mobility'},
#  {u'address': u'4 Hillary Square Orewa Orewa',
#   u'id': u'136',
#   u'latitude': -36.585656,
#   u'longitude': 174.694118,
#   u'mobilitySpaces': 2,
#   u'name': u'Located in Hillary Square South , two P180 angle parks with central drop kerb ',
#   u'type': u'mobility'},
#  {u'address': u' Keith Morris Lane Orewa Orewa',
#   u'id': u'137',
#   u'latitude': -36.587054,
#   u'longitude': 174.693725,
#   u'mobilitySpaces': 1,
#   u'name': u'Opposite Unichem P180 angle park with drop kerb',
#   u'type': u'mobility'},
#  {u'address': u'40 Orewa Square Orewa Orewa',
#   u'id': u'138',
#   u'latitude': -36.585777,
#   u'longitude': 174.694971,
#   u'mobilitySpaces': 3,
#   u'name': u'P180 angle parks with drop kerb',
#   u'type': u'mobility'},
#  {u'address': u'15 Tamariki Avenue Orewa Orewa',
#   u'id': u'139',
#   u'latitude': -36.58773,
#   u'longitude': 174.694302,
#   u'mobilitySpaces': 1,
#   u'name': u'P180 angle park with drop kerb on passenger side, located outside the Nautilus Building',
#   u'type': u'mobility'},
#  {u'address': u' Tamariki Avenue Orewa Orewa',
#   u'id': u'140',
#   u'latitude': -36.587261,
#   u'longitude': 174.696377,
#   u'mobilitySpaces': 1,
#   u'name': u'P180 angle park with ramp access to footpath, located outside Care Chemist.',
#   u'type': u'mobility'},
#  {u'address': u'332  Hibiscus Coast Highway Orewa Orewa',
#   u'id': u'141',
#   u'latitude': -36.58664,
#   u'longitude': 174.696311,
#   u'mobilitySpaces': 0,
#   u'name': u'',
#   u'type': u'motorcycle'},
#  {u'address': u'12 Shortland Street CBD Auckland',
#   u'id': u'142',
#   u'latitude': -36.846451,
#   u'longitude': 174.766696,
#   u'mobilitySpaces': 2,
#   u'name': u'P180 parallel spaces with ramp access',
#   u'type': u'mobility'},
#  {u'address': u' Rutland Street Auckland Auckland',
#   u'id': u'143',
#   u'latitude': -36.852113,
#   u'longitude': 174.765236,
#   u'mobilitySpaces': 3,
#   u'name': u'Outside Auckland Library P120 parallel spaces on flush surface',
#   u'type': u'mobility'},
#  {u'address': u' Hobson Street Auckland Auckland',
#   u'id': u'144',
#   u'latitude': -36.847386,
#   u'longitude': 174.762036,
#   u'mobilitySpaces': 2,
#   u'name': u'P180 parallel spaces outside of Pizza Hut near corner of Kingston Street.',
#   u'type': u'mobility'},
#  {u'address': u' Customs Street West Auckland Auckland',
#   u'id': u'145',
#   u'latitude': -36.843338,
#   u'longitude': 174.760973,
#   u'mobilitySpaces': 1,
#   u'name': u'Opposite 110. P120 Angle next to public toilet.',
#   u'type': u'mobility'},
#  {u'address': u'32 Mokoia Road Birkenhead Birkenhead',
#   u'id': u'146',
#   u'latitude': -36.812137,
#   u'longitude': 174.725061,
#   u'mobilitySpaces': 2,
#   u'name': u'P120 angle parks with kerb cutting for access',
#   u'type': u'mobility'},
#  {u'address': u'204 Hinemoa Street Birkenhead Birkenhead',
#   u'id': u'148',
#   u'latitude': -36.81272,
#   u'longitude': 174.726859,
#   u'mobilitySpaces': 2,
#   u'name': u'Not time restricted parallel parks outside of the Library. Other mobility spaces are available on Rawene Road and underneath the library during library hours. ',
#   u'type': u'mobility'}]

# %%
savpark.getparks()
# Out:
# [{u'address': u' Beach Road Te Atatu North Auckland',
#   u'id': u'2',
#   u'latitude': -36.828734,
#   u'longitude': 174.656176,
#   u'mobilitySpaces': 0,
#   u'name': u'Beach Road Carpark, Te Atatu North',
#   u'type': u'all'},
#  {u'address': u'5 City Rd Grafton Auckland',
#   u'id': u'3',
#   u'latitude': -36.856949,
#   u'longitude': 174.7639059,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 5-7 City Road',
#   u'type': u'motorcycle'},
#  {u'address': u' Harbour View Road Te Atatu Penisula Auckland',
#   u'id': u'4',
#   u'latitude': -36.839193,
#   u'longitude': 174.66168,
#   u'mobilitySpaces': 0,
#   u'name': u'Harbour View Road Carpark, Te Atatu Penisula',
#   u'type': u'all'},
#  {u'address': u'6 Burleigh St Grafton Auckland',
#   u'id': u'5',
#   u'latitude': -36.8649142,
#   u'longitude': 174.7625287,
#   u'mobilitySpaces': 0,
#   u'name': u'Burleigh Street, Grafton (Corner Burleigh and Khyber Pass Road)',
#   u'type': u'all'},
#  {u'address': u' McLeod Road Te Atatu South Auckland',
#   u'id': u'6',
#   u'latitude': -36.875892,
#   u'longitude': 174.655774,
#   u'mobilitySpaces': 0,
#   u'name': u'McLeod Road Carpark, Te Atatu South',
#   u'type': u'all'},
#  {u'address': u' Glenmall Place Glen Eden Auckland',
#   u'id': u'8',
#   u'latitude': -36.911239,
#   u'longitude': 174.651997,
#   u'mobilitySpaces': 0,
#   u'name': u'Glenmall Place Carpark, Glen Eden (Mobility, P45, P125, LZ',
#   u'type': u'all'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'9',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes 6 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Matipo Road Te Atatu Peninsula Auckland',
#   u'id': u'10',
#   u'latitude': -36.837484,
#   u'longitude': 174.642153,
#   u'mobilitySpaces': 0,
#   u'name': u'Matipo Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Mayoral Drive CBD Auckland',
#   u'id': u'11',
#   u'latitude': -36.853726,
#   u'longitude': 174.76451,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking opposite the Open Polytechnic at 120 Mayoral Drive',
#   u'type': u'mobility'},
#  {u'address': u' Old Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'12',
#   u'latitude': -36.84893,
#   u'longitude': 174.651021,
#   u'mobilitySpaces': 0,
#   u'name': u'Old Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'30 Princes Street CBD Auckland',
#   u'id': u'13',
#   u'latitude': -36.851495,
#   u'longitude': 174.768538,
#   u'mobilitySpaces': 3,
#   u'name': u'On street mobility parking outside the Maidement Art Centre',
#   u'type': u'mobility'},
#  {u'address': u' South Titirangi Road Titirangi Auckland',
#   u'id': u'14',
#   u'latitude': -36.938865,
#   u'longitude': 174.655945,
#   u'mobilitySpaces': 0,
#   u'name': u'South Titirangi Road Carpark, Titirangi (Mobililty)',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'15',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 15,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes 15 Mobility parking spaces on the ground level. ',
#   u'type': u'all'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'16',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Granville Road Royal Heights Auckland',
#   u'id': u'17',
#   u'latitude': -36.828674,
#   u'longitude': 174.628286,
#   u'mobilitySpaces': 0,
#   u'name': u'Granville Road Carpark, Royal Heights',
#   u'type': u'all'},
#  {u'address': u'45 Airedale Street CBD Auckland',
#   u'id': u'18',
#   u'latitude': -36.854895,
#   u'longitude': 174.764762,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking',
#   u'type': u'mobility'},
#  {u'address': u' Henderson Valley Road Henderson Auckland',
#   u'id': u'20',
#   u'latitude': -36.894187,
#   u'longitude': 174.616538,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Valley Road, Henderson',
#   u'type': u'all'},
#  {u'address': u' Henderson Park Henderson Auckland',
#   u'id': u'21',
#   u'latitude': -36.878807,
#   u'longitude': 174.625255,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Park, Henderson',
#   u'type': u'all'},
#  {u'address': u' Waipareira Avenue Lincoln Auckland',
#   u'id': u'22',
#   u'latitude': -36.865017,
#   u'longitude': 174.633173,
#   u'mobilitySpaces': 0,
#   u'name': u'Waipareira Avenue Carpark (Mobility), Lincoln',
#   u'type': u'all'},
#  {u'address': u' Withers Road Glen Eden Auckland',
#   u'id': u'23',
#   u'latitude': -36.926616,
#   u'longitude': 174.643081,
#   u'mobilitySpaces': 0,
#   u'name': u'Withers Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u'24 Wellesley St W Auckland Auckland',
#   u'id': u'24',
#   u'latitude': -36.8508833,
#   u'longitude': 174.7632388,
#   u'mobilitySpaces': 0,
#   u'name': u'Bledisloe',
#   u'type': u'all'},
#  {u'address': u' Titirangi Road Titirangi Auckland',
#   u'id': u'25',
#   u'latitude': -36.938091,
#   u'longitude': 174.656181,
#   u'mobilitySpaces': 0,
#   u'name': u'Titirangi Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Clearwater Cove , Royal Heights Auckland',
#   u'id': u'26',
#   u'latitude': -36.810603,
#   u'longitude': 174.645184,
#   u'mobilitySpaces': 0,
#   u'name': u'Clearwater Cove Carpark, Royal Heights',
#   u'type': u'all'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'27',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'28',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 21,
#   u'name': u'Multi storey parking facility under Aotea square. Includes 21 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u' Titirangi Road Titirangi Auckland',
#   u'id': u'29',
#   u'latitude': -36.938134,
#   u'longitude': 174.655441,
#   u'mobilitySpaces': 0,
#   u'name': u'Titirangi Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Taikata Road Te Atatu Peninsula Auckland',
#   u'id': u'30',
#   u'latitude': -36.836561,
#   u'longitude': 174.638983,
#   u'mobilitySpaces': 0,
#   u'name': u'Taikata Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'22 Symonds St CBD Auckland',
#   u'id': u'31',
#   u'latitude': -36.853223,
#   u'longitude': 174.7696247,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 20-26 Symonds Street',
#   u'type': u'motorcycle'},
#  {u'address': u'21 Federal Street CBD Auckland',
#   u'id': u'32',
#   u'latitude': -36.84553,
#   u'longitude': 174.763762,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking on corner of Federal and Swanson Street',
#   u'type': u'mobility'},
#  {u'address': u'100-102 Customs Street West CBD Auckland',
#   u'id': u'33',
#   u'latitude': -36.843747,
#   u'longitude': 174.763149,
#   u'mobilitySpaces': 2,
#   u'name': u'On Street mobility parking outside Auckland Tepid Baths.  ',
#   u'type': u'mobility'},
#  {u'address': u'34 Airedale St CBD Auckland',
#   u'id': u'34',
#   u'latitude': -36.8546386,
#   u'longitude': 174.7648333,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 34 Airdale Street',
#   u'type': u'motorcycle'},
#  {u'address': u'2 Chancery St CBD Auckland',
#   u'id': u'35',
#   u'latitude': -36.8476481,
#   u'longitude': 174.7671923,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 2-8 Chancery Street',
#   u'type': u'motorcycle'},
#  {u'address': u'123 Pakenham St W CBD Auckland',
#   u'id': u'36',
#   u'latitude': -36.843373,
#   u'longitude': 174.7562491,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 117- 139 Pakenham Street West',
#   u'type': u'motorcycle'},
#  {u'address': u'20 Upper Queen St Auckland Auckland',
#   u'id': u'37',
#   u'latitude': -36.8589737,
#   u'longitude': 174.7615222,
#   u'mobilitySpaces': 0,
#   u'name': u'Upper Queen Street,(opposite Cross Street)',
#   u'type': u'all'},
#  {u'address': u' West Coast Road Glen Eden Auckland',
#   u'id': u'38',
#   u'latitude': -36.910222,
#   u'longitude': 174.652512,
#   u'mobilitySpaces': 0,
#   u'name': u'West Coast Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u' 64 CBD Auckland',
#   u'id': u'39',
#   u'latitude': -36.854233,
#   u'longitude': 174.761174,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking near Myers Park',
#   u'type': u'mobility'},
#  {u'address': u' Ratanui Street Henderson Auckland',
#   u'id': u'40',
#   u'latitude': -36.879194,
#   u'longitude': 174.632591,
#   u'mobilitySpaces': 0,
#   u'name': u'Ratanui Street Carpark (Mobility), Henderson',
#   u'type': u'all'},
#  {u'address': u' Edmonton Road Henderson Auckland',
#   u'id': u'41',
#   u'latitude': -36.878235,
#   u'longitude': 174.634761,
#   u'mobilitySpaces': 0,
#   u'name': u'Edmonton Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Robertson Road Ranui Auckland',
#   u'id': u'42',
#   u'latitude': -36.866566,
#   u'longitude': 174.600456,
#   u'mobilitySpaces': 0,
#   u'name': u'Robertson Road Carpark, Ranui',
#   u'type': u'all'},
#  {u'address': u'9 Wolfe Street CBD Auckland',
#   u'id': u'43',
#   u'latitude': -36.844975,
#   u'longitude': 174.764319,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking',
#   u'type': u'mobility'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'44',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes 6 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'22 Princes Street CBD Auckland',
#   u'id': u'45',
#   u'latitude': -36.850084,
#   u'longitude': 174.769182,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside Auckland University Clock Tower',
#   u'type': u'mobility'},
#  {u'address': u'112 Parnell Rd Parnell Auckland',
#   u'id': u'47',
#   u'latitude': -36.852955,
#   u'longitude': 174.7790622,
#   u'mobilitySpaces': 0,
#   u'name': u'112 Parnell Road (Entrance off Garfield street) \u200b',
#   u'type': u'all'},
#  {u'address': u'7 Elliott St CBD Auckland',
#   u'id': u'48',
#   u'latitude': -36.8492861,
#   u'longitude': 174.7640473,
#   u'mobilitySpaces': 0,
#   u'name': u'Cnr Elliot & Victoria Streets, Auckland',
#   u'type': u'motorcycle'},
#  {u'address': u' La Rosa Street Green Bay Auckland',
#   u'id': u'49',
#   u'latitude': -36.9304,
#   u'longitude': 174.67526,
#   u'mobilitySpaces': 0,
#   u'name': u'La Rosa Street Carpark, Green Bay',
#   u'type': u'all'},
#  {u'address': u'2 Daldy St CBD Auckland',
#   u'id': u'50',
#   u'latitude': -36.8451709,
#   u'longitude': 174.7539487,
#   u'mobilitySpaces': 0,
#   u'name': u'Opposite 2 Daldy Street',
#   u'type': u'motorcycle'},
#  {u'address': u' Sel Peacock Driven Henderson Auckland',
#   u'id': u'51',
#   u'latitude': -36.879194,
#   u'longitude': 174.632591,
#   u'mobilitySpaces': 0,
#   u'name': u'Sel Peacock Drive (Mobility), Henderson',
#   u'type': u'all'},
#  {u'address': u' Binstead Road Kelston Auckland',
#   u'id': u'52',
#   u'latitude': -36.901476,
#   u'longitude': 174.681416,
#   u'mobilitySpaces': 0,
#   u'name': u'Binstead Road Carpark, Kelston',
#   u'type': u'all'},
#  {u'address': u'16 Eden Crescent CBD Auckland',
#   u'id': u'53',
#   u'latitude': -36.8481902,
#   u'longitude': 174.7720016,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 16-18 Eden Crescent ',
#   u'type': u'motorcycle'},
#  {u'address': u' Totara Avenue New Lynn Auckland',
#   u'id': u'54',
#   u'latitude': -36.910003,
#   u'longitude': 174.68134,
#   u'mobilitySpaces': 0,
#   u'name': u'Totara Avenue Carpark, New Lynn (Mobility, P240)',
#   u'type': u'all'},
#  {u'address': u' Swanson Road Henderson Auckland',
#   u'id': u'55',
#   u'latitude': -36.872744,
#   u'longitude': 174.620967,
#   u'mobilitySpaces': 0,
#   u'name': u'Swanson Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'56',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Whatipu Road Huia Auckland',
#   u'id': u'57',
#   u'latitude': -37.016732,
#   u'longitude': 174.553378,
#   u'mobilitySpaces': 0,
#   u'name': u'Whatipu Road Carpark, Huia',
#   u'type': u'all'},
#  {u'address': u' Beaubank Road  Kelston Beaubank Road  Kelston Auckland',
#   u'id': u'58',
#   u'latitude': -36.896336,
#   u'longitude': 174.671824,
#   u'mobilitySpaces': 0,
#   u'name': u'Beaubank Road Carpark, Kelston',
#   u'type': u'all'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'59',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 4,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes 4 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Central Park Drive Henderson Auckland',
#   u'id': u'60',
#   u'latitude': -36.86321,
#   u'longitude': 174.636338,
#   u'mobilitySpaces': 0,
#   u'name': u'Central Park Drive Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'2 Kitchener Street CBD Auckland',
#   u'id': u'61',
#   u'latitude': -36.850649,
#   u'longitude': 174.766161,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking near the Auckland Art Gallery',
#   u'type': u'mobility'},
#  {u'address': u'182 Federal St CBD Auckland',
#   u'id': u'62',
#   u'latitude': -36.8504856,
#   u'longitude': 174.7617902,
#   u'mobilitySpaces': 0,
#   u'name': u'Cnr Federal & Wellesley Streets, Auckland',
#   u'type': u'motorcycle'},
#  {u'address': u'65 Federal Street CBD Auckland',
#   u'id': u'63',
#   u'latitude': -36.847672,
#   u'longitude': 174.762814,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 65 Federal Street',
#   u'type': u'mobility'},
#  {u'address': u'48 Market Place CBD Auckland',
#   u'id': u'64',
#   u'latitude': -36.843579,
#   u'longitude': 174.761774,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 48 Market Place',
#   u'type': u'mobility'},
#  {u'address': u'57 Anzac Avenue CBD Auckland',
#   u'id': u'65',
#   u'latitude': -36.847314,
#   u'longitude': 174.772383,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking, outside the New Zealand Customs building',
#   u'type': u'mobility'},
#  {u'address': u'11 St Paul Street CBD Auckland',
#   u'id': u'66',
#   u'latitude': -36.8539462,
#   u'longitude': 174.7673425,
#   u'mobilitySpaces': 0,
#   u'name': u'11 St Paul Street, Auckland, New Zealand',
#   u'type': u'motorcycle'},
#  {u'address': u' Marine Parade Piha Auckland',
#   u'id': u'67',
#   u'latitude': -36.955628,
#   u'longitude': 174.468373,
#   u'mobilitySpaces': 0,
#   u'name': u'Marine Parade South (North Carpark), Piha (Mobility)',
#   u'type': u'all'},
#  {u'address': u' Marine Parade Piha Auckland',
#   u'id': u'68',
#   u'latitude': -36.957587,
#   u'longitude': 174.468142,
#   u'mobilitySpaces': 0,
#   u'name': u'Marine Parade South (South Carpark), Piha',
#   u'type': u'all'},
#  {u'address': u' Essex Street Henderson Auckland',
#   u'id': u'69',
#   u'latitude': -36.87171,
#   u'longitude': 174.642915,
#   u'mobilitySpaces': 0,
#   u'name': u'Essex Street Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Turner Street CBD Auckland',
#   u'id': u'70',
#   u'latitude': -36.855519,
#   u'longitude': 174.763256,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking, opposite Auckland International YHA',
#   u'type': u'mobility'},
#  {u'address': u'125 Customs Street West CBD Auckland',
#   u'id': u'71',
#   u'latitude': -36.84382,
#   u'longitude': 174.760361,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 125 Customs Street West',
#   u'type': u'mobility'},
#  {u'address': u'9-11 Symonds St CBD Auckland',
#   u'id': u'72',
#   u'latitude': -36.8522447,
#   u'longitude': 174.7697629,
#   u'mobilitySpaces': 0,
#   u'name': u'Outside 9 -11 Symonds Street',
#   u'type': u'motorcycle'},
#  {u'address': u' Great North Road Henderson Auckland',
#   u'id': u'73',
#   u'latitude': -36.87171,
#   u'longitude': 174.642915,
#   u'mobilitySpaces': 0,
#   u'name': u'Great North Road (426) Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'30 Kitchener Street CBD Auckland',
#   u'id': u'74',
#   u'latitude': -36.8489848,
#   u'longitude': 174.766856,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark building with 850 spaces on twenty levels.  Includes 6 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Te Pai Place Lincoln Auckland',
#   u'id': u'76',
#   u'latitude': -36.862047,
#   u'longitude': 174.632884,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Pai Place Carpark, Lincoln',
#   u'type': u'all'},
#  {u'address': u'26-46 Te Taou Crescent CBD Auckland',
#   u'id': u'77',
#   u'latitude': -36.848544,
#   u'longitude': 174.776416,
#   u'mobilitySpaces': 5,
#   u'name': u'On street mobility parking beside the old Grand Central Station, next to Vector Arena.',
#   u'type': u'mobility'},
#  {u'address': u' Anzac Street Takapuna, Auckland',
#   u'id': u'78',
#   u'latitude': -36.786656,
#   u'longitude': 174.77127,
#   u'mobilitySpaces': 0,
#   u'name': u'Anzac Street, Takapuna. Includes 8 Mobility parking spaces.',
#   u'type': u'all'},
#  {u'address': u' Tyler Street CBD Auckland',
#   u'id': u'79',
#   u'latitude': -36.844474,
#   u'longitude': 174.770004,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking, halfway down Tyler Street.',
#   u'type': u'mobility'},
#  {u'address': u' Glendale Road Glen Eden Auckland',
#   u'id': u'80',
#   u'latitude': -36.9204,
#   u'longitude': 174.649508,
#   u'mobilitySpaces': 0,
#   u'name': u'Glendale Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u'52-60 Federal Street CDB Auckland',
#   u'id': u'81',
#   u'latitude': -36.847889,
#   u'longitude': 174.762807,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking outside 60 Federal Street',
#   u'type': u'mobility'},
#  {u'address': u'51 High Street CBD Auckland',
#   u'id': u'82',
#   u'latitude': -36.848418,
#   u'longitude': 174.766358,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking outside 51 High Street',
#   u'type': u'mobility'},
#  {u'address': u' Don Buck Road Massey Auckland',
#   u'id': u'88',
#   u'latitude': -36.834427,
#   u'longitude': 174.603058,
#   u'mobilitySpaces': 0,
#   u'name': u'Don Buck Road Carpark, Massey',
#   u'type': u'all'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'90',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'20 Greys Ave Auckland Auckland',
#   u'id': u'91',
#   u'latitude': -36.8528506,
#   u'longitude': 174.7630503,
#   u'mobilitySpaces': 0,
#   u'name': u'Greys Ave\u200b (opposite the Civic Building)',
#   u'type': u'all'},
#  {u'address': u' Parrs Cross Road Glen Eden Auckland',
#   u'id': u'92',
#   u'latitude': -36.906675,
#   u'longitude': 174.627723,
#   u'mobilitySpaces': 0,
#   u'name': u'Parrs Cross Road Carpark, Glen Eden/Oratia',
#   u'type': u'all'},
#  {u'address': u' Great North Road New Lynn Auckland',
#   u'id': u'93',
#   u'latitude': -36.908669,
#   u'longitude': 174.682869,
#   u'mobilitySpaces': 0,
#   u'name': u'Great North Road (3072) Carpark, New Lynn (Mobility, P120, P180, LZ)',
#   u'type': u'all'},
#  {u'address': u'360 Queen Street CBD Auckland',
#   u'id': u'94',
#   u'latitude': -36.852541,
#   u'longitude': 174.763875,
#   u'mobilitySpaces': 3,
#   u'name': u'On street mobility parking opposite the Town Hall',
#   u'type': u'mobility'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'95',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 9,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes 9 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'96',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 21,
#   u'name': u'Multi storey parking facility under Aotea square. Includes 21 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u' Taitoki Street Te Atatu Peninsula Auckland',
#   u'id': u'97',
#   u'latitude': -36.855158,
#   u'longitude': 174.647405,
#   u'mobilitySpaces': 0,
#   u'name': u'Taitoki Street Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'33 Wyndham Street CBD Auckland',
#   u'id': u'98',
#   u'latitude': -36.846787,
#   u'longitude': 174.763832,
#   u'mobilitySpaces': 1,
#   u'name': u'On street mobility parking near St Patricks Church.',
#   u'type': u'mobility'},
#  {u'address': u'126 Beach Rd Auckland Auckland',
#   u'id': u'99',
#   u'latitude': -36.8482474,
#   u'longitude': 174.7746586,
#   u'mobilitySpaces': 0,
#   u'name': u' Railway station, Beach Road,(Opposite Tai Ping Supermarket)',
#   u'type': u'all'},
#  {u'address': u' Don Buck Road Massey Auckland',
#   u'id': u'100',
#   u'latitude': -36.836016,
#   u'longitude': 174.60228,
#   u'mobilitySpaces': 0,
#   u'name': u'Don Buck Road Carpark (P60), Massey',
#   u'type': u'all'},
#  {u'address': u'70 The Strand Parnell Auckland',
#   u'id': u'101',
#   u'latitude': -36.8495918,
#   u'longitude': 174.7813795,
#   u'mobilitySpaces': 0,
#   u'name': u'Corner of The Strand and St Georges Bay Rd Parnell\r\n(Opposite Saatchi & Saatchi)',
#   u'type': u'all'},
#  {u'address': u' Huia Road Titirangi Auckland',
#   u'id': u'102',
#   u'latitude': -36.949007,
#   u'longitude': 174.641781,
#   u'mobilitySpaces': 0,
#   u'name': u'Huia Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Willerton Avenue New Lynn Auckland',
#   u'id': u'103',
#   u'latitude': -36.918028,
#   u'longitude': 174.674769,
#   u'mobilitySpaces': 0,
#   u'name': u'Willerton Avenue Carpark, New Lynn',
#   u'type': u'all'},
#  {u'address': u' Parliament Street CBD Auckland',
#   u'id': u'104',
#   u'latitude': -36.849366,
#   u'longitude': 174.771821,
#   u'mobilitySpaces': 2,
#   u'name': u'On street mobility parking Beside the Auckland High Court on the corner of Parliament Street and Waterloo Quadrant.',
#   u'type': u'mobility'},
#  {u'address': u' Neil Avenue Te Atatu Peninsula Auckland',
#   u'id': u'105',
#   u'latitude': -36.838506,
#   u'longitude': 174.646236,
#   u'mobilitySpaces': 0,
#   u'name': u'Neil Avenue Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'106',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u' Atkinson Road Titirangi Auckland',
#   u'id': u'107',
#   u'latitude': -36.924105,
#   u'longitude': 174.655522,
#   u'mobilitySpaces': 0,
#   u'name': u'Atkinson Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Atkinson Road Titirangi Auckland',
#   u'id': u'108',
#   u'latitude': -36.927017,
#   u'longitude': 174.655049,
#   u'mobilitySpaces': 0,
#   u'name': u'Atkinson Road Carpark, Titirangi',
#   u'type': u'all'},
#  {u'address': u' Henderson Valley Road Henderson Auckland',
#   u'id': u'109',
#   u'latitude': -36.878702,
#   u'longitude': 174.629772,
#   u'mobilitySpaces': 0,
#   u'name': u'Henderson Valley Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'110',
#   u'latitude': -36.841509,
#   u'longitude': 174.651855,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Wilsher Road Henderson Auckland',
#   u'id': u'112',
#   u'latitude': -36.878807,
#   u'longitude': 174.625255,
#   u'mobilitySpaces': 0,
#   u'name': u'Wilsher Road Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u' Te Atatu Road Te Atatu Peninsula Auckland',
#   u'id': u'113',
#   u'latitude': -36.840558,
#   u'longitude': 174.651576,
#   u'mobilitySpaces': 0,
#   u'name': u'Te Atatu Road Carpark, Te Atatu Peninsula',
#   u'type': u'all'},
#  {u'address': u' Moselle Avenue Lincoln Auckland',
#   u'id': u'114',
#   u'latitude': -36.864442,
#   u'longitude': 174.629686,
#   u'mobilitySpaces': 0,
#   u'name': u'Moselle Avenue Carpark (Mobility), Lincoln',
#   u'type': u'all'},
#  {u'address': u' Edmonton Road Te Atatu South Auckland',
#   u'id': u'115',
#   u'latitude': -36.866002,
#   u'longitude': 174.645313,
#   u'mobilitySpaces': 0,
#   u'name': u'Edmonton Road Carpark, Te Atatu South',
#   u'type': u'all'},
#  {u'address': u'18 Ronwood Avenue Manukau Auckland',
#   u'id': u'116',
#   u'latitude': -36.991016,
#   u'longitude': 174.877815,
#   u'mobilitySpaces': 15,
#   u'name': u'Multi-storey parking facility with 676 spaces on eight levels. Includes 15 Mobility parking spaces on the ground level. ',
#   u'type': u'mobility'},
#  {u'address': u'24 Mercury Lane CBD Auckland',
#   u'id': u'117',
#   u'latitude': -36.8589093,
#   u'longitude': 174.7594077,
#   u'mobilitySpaces': 6,
#   u'name': u'Multi-storey carpark with 570 spaces for both public and leaseholder parking.  Includes 6 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u' Red Hills Road Massey Auckland',
#   u'id': u'118',
#   u'latitude': -36.837502,
#   u'longitude': 174.598779,
#   u'mobilitySpaces': 0,
#   u'name': u'Red Hills Road Carpark, Massey',
#   u'type': u'all'},
#  {u'address': u' Alderman Drive Henderson Auckland',
#   u'id': u'119',
#   u'latitude': -36.877651,
#   u'longitude': 174.634976,
#   u'mobilitySpaces': 0,
#   u'name': u'Alderman Drive Carpark, Henderson',
#   u'type': u'all'},
#  {u'address': u'1 Greys Avenue CBD Auckland',
#   u'id': u'121',
#   u'latitude': -36.853072,
#   u'longitude': 174.762515,
#   u'mobilitySpaces': 0,
#   u'name': u'Multi storey parking facility under Aotea square. Includes motorcycle parking',
#   u'type': u'motorcycle'},
#  {u'address': u'12-42 Ngaoho Pl Parnell Auckland',
#   u'id': u'122',
#   u'latitude': -36.8493662,
#   u'longitude': 174.7768046,
#   u'mobilitySpaces': 0,
#   u'name': u'Ngaoho Place\u200b',
#   u'type': u'all'},
#  {u'address': u' West Coast Road Glen Eden Auckland',
#   u'id': u'123',
#   u'latitude': -36.909999,
#   u'longitude': 174.651724,
#   u'mobilitySpaces': 0,
#   u'name': u'West Coast Road Carpark, Glen Eden',
#   u'type': u'all'},
#  {u'address': u' Hugh Brown Drive New Lynn Auckland',
#   u'id': u'124',
#   u'latitude': -36.906947,
#   u'longitude': 174.681201,
#   u'mobilitySpaces': 0,
#   u'name': u'Hugh Brown Drive Carpark, New Lynn',
#   u'type': u'all'},
#  {u'address': u'21 St Paul Street CBD Auckland',
#   u'id': u'125',
#   u'latitude': -36.8539,
#   u'longitude': 174.766939,
#   u'mobilitySpaces': 4,
#   u'name': u'On street mobility parking outside AUT (AUckland University of Technology) D Block.',
#   u'type': u'mobility'},
#  {u'address': u'72-100 Fanshaw Street CBD Auckland',
#   u'id': u'126',
#   u'latitude': -36.8459021,
#   u'longitude': 174.7598652,
#   u'mobilitySpaces': 4,
#   u'name': u'Multi-storey carpark with 509 spaces for public and leaseholder parking.  Includes 4 Mobility parking spaces. ',
#   u'type': u'all'},
#  {u'address': u'31 Customs Street West CBD Auckland',
#   u'id': u'127',
#   u'latitude': -36.8439069,
#   u'longitude': 174.7642207,
#   u'mobilitySpaces': 9,
#   u'name': u'Multi-storey parking facility on the corner of Lower Hobson Street and Customs Street West.  Includes 9 Mobility parking spaces. ',
#   u'type': u'mobility'},
#  {u'address': u'30 McCrae Way New Lynn Auckland',
#   u'id': u'128',
#   u'latitude': -36.909199,
#   u'longitude': 174.68318,
#   u'mobilitySpaces': 12,
#   u'name': u'Multi-storey pay and display parking facility under Totara Medical Centre. Three levels with 70 parking spaces and 4 mobility spaces on each level. The first level is reserved for visitors to the Totara Medical Centre. Limited motorcycle parking in designated areas.\r\n',
#   u'type': u'all'},
#  {u'address': u'14 Trading Place Henderson Auckland',
#   u'id': u'129',
#   u'latitude': -36.878711,
#   u'longitude': 174.633626,
#   u'mobilitySpaces': 7,
#   u'name': u'Henderson library/Unitec car park',
#   u'type': u'all'},
#  {u'address': u'7-9 Oceanview Rd Oneroa Auckland',
#   u'id': u'130',
#   u'latitude': -36.781143,
#   u'longitude': 174.993854,
#   u'mobilitySpaces': 12,
#   u'name': u'Matiatia car park (Waiheke Island)',
#   u'type': u'all'},
#  {u'address': u'22 Beresford Square CBD Auckland',
#   u'id': u'131',
#   u'latitude': -36.856566,
#   u'longitude': 174.757762,
#   u'mobilitySpaces': 0,
#   u'name': u'Beresford Square car park',
#   u'type': u'all'},
#  {u'address': u'1429 Sandspit Rd Sandspit Auckland',
#   u'id': u'132',
#   u'latitude': -36.390447,
#   u'longitude': 174.728553,
#   u'mobilitySpaces': 0,
#   u'name': u'Sandspit Road, Sandspit, off State Highway 1',
#   u'type': u'all'},
#  {u'address': u'4 Bakehouse Lane  Orewa Orewa',
#   u'id': u'133',
#   u'latitude': -36.586509,
#   u'longitude': 174.695507,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle park with drop kerb access ',
#   u'type': u'mobility'},
#  {u'address': u'18 Bakehouse Lane Orewa Orewa',
#   u'id': u'134',
#   u'latitude': -36.587053,
#   u'longitude': 174.695738,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle park with drop kerb ',
#   u'type': u'mobility'},
#  {u'address': u'15 Florence Street Orewa Orewa',
#   u'id': u'135',
#   u'latitude': -36.585012,
#   u'longitude': 174.693935,
#   u'mobilitySpaces': 1,
#   u'name': u'On street P180 angle space located in Hillary Square North, outside the Red Cross Shop .',
#   u'type': u'mobility'},
#  {u'address': u'4 Hillary Square Orewa Orewa',
#   u'id': u'136',
#   u'latitude': -36.585656,
#   u'longitude': 174.694118,
#   u'mobilitySpaces': 2,
#   u'name': u'Located in Hillary Square South , two P180 angle parks with central drop kerb ',
#   u'type': u'mobility'},
#  {u'address': u' Keith Morris Lane Orewa Orewa',
#   u'id': u'137',
#   u'latitude': -36.587054,
#   u'longitude': 174.693725,
#   u'mobilitySpaces': 1,
#   u'name': u'Opposite Unichem P180 angle park with drop kerb',
#   u'type': u'mobility'},
#  {u'address': u'40 Orewa Square Orewa Orewa',
#   u'id': u'138',
#   u'latitude': -36.585777,
#   u'longitude': 174.694971,
#   u'mobilitySpaces': 3,
#   u'name': u'P180 angle parks with drop kerb',
#   u'type': u'mobility'},
#  {u'address': u'15 Tamariki Avenue Orewa Orewa',
#   u'id': u'139',
#   u'latitude': -36.58773,
#   u'longitude': 174.694302,
#   u'mobilitySpaces': 1,
#   u'name': u'P180 angle park with drop kerb on passenger side, located outside the Nautilus Building',
#   u'type': u'mobility'},
#  {u'address': u' Tamariki Avenue Orewa Orewa',
#   u'id': u'140',
#   u'latitude': -36.587261,
#   u'longitude': 174.696377,
#   u'mobilitySpaces': 1,
#   u'name': u'P180 angle park with ramp access to footpath, located outside Care Chemist.',
#   u'type': u'mobility'},
#  {u'address': u'332  Hibiscus Coast Highway Orewa Orewa',
#   u'id': u'141',
#   u'latitude': -36.58664,
#   u'longitude': 174.696311,
#   u'mobilitySpaces': 0,
#   u'name': u'',
#   u'type': u'motorcycle'},
#  {u'address': u'12 Shortland Street CBD Auckland',
#   u'id': u'142',
#   u'latitude': -36.846451,
#   u'longitude': 174.766696,
#   u'mobilitySpaces': 2,
#   u'name': u'P180 parallel spaces with ramp access',
#   u'type': u'mobility'},
#  {u'address': u' Rutland Street Auckland Auckland',
#   u'id': u'143',
#   u'latitude': -36.852113,
#   u'longitude': 174.765236,
#   u'mobilitySpaces': 3,
#   u'name': u'Outside Auckland Library P120 parallel spaces on flush surface',
#   u'type': u'mobility'},
#  {u'address': u' Hobson Street Auckland Auckland',
#   u'id': u'144',
#   u'latitude': -36.847386,
#   u'longitude': 174.762036,
#   u'mobilitySpaces': 2,
#   u'name': u'P180 parallel spaces outside of Pizza Hut near corner of Kingston Street.',
#   u'type': u'mobility'},
#  {u'address': u' Customs Street West Auckland Auckland',
#   u'id': u'145',
#   u'latitude': -36.843338,
#   u'longitude': 174.760973,
#   u'mobilitySpaces': 1,
#   u'name': u'Opposite 110. P120 Angle next to public toilet.',
#   u'type': u'mobility'},
#  {u'address': u'32 Mokoia Road Birkenhead Birkenhead',
#   u'id': u'146',
#   u'latitude': -36.812137,
#   u'longitude': 174.725061,
#   u'mobilitySpaces': 2,
#   u'name': u'P120 angle parks with kerb cutting for access',
#   u'type': u'mobility'},
#  {u'address': u'204 Hinemoa Street Birkenhead Birkenhead',
#   u'id': u'148',
#   u'latitude': -36.81272,
#   u'longitude': 174.726859,
#   u'mobilitySpaces': 2,
#   u'name': u'Not time restricted parallel parks outside of the Library. Other mobility spaces are available on Rawene Road and underneath the library during library hours. ',
#   u'type': u'mobility'}]
